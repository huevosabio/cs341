# %%
import math
import numpy as np
import pandas as pd
import os
import tempfile

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
rebdf = pd.read_csv('ignored_assets/rebtrips.csv', parse_dates = [6,11])

# %%
rebdf
# Out:
#                                  order_id                         driver_id  \
# 0        bd6e66f80f0e128586197e6996359b5b  0000764e702cb5b1f4a27b6681ddf4d2
# 1        9cc4f12aafe4b797db9af25288cd3a12  000126baf2f8839eed1df6a726f79549
# 2        ccc8e6c38e01cd29940e80477e689075  000126baf2f8839eed1df6a726f79549
# 3        f1ab4820b4a05f7324bafcc90ed2c7b3  000126baf2f8839eed1df6a726f79549
# 4        1b3df6bed6435972a3a7d8741e030b61  000126baf2f8839eed1df6a726f79549
# 5        48acb476cf91ff43b084a284f8a35a8a  000126baf2f8839eed1df6a726f79549
# 6        759a19ca0b94ef43cf95c4058c648930  000126baf2f8839eed1df6a726f79549
# 7        94775a41311fefc7c10199b721828793  000126baf2f8839eed1df6a726f79549
# 8        daaa597044df630f352b635f821c0157  000126baf2f8839eed1df6a726f79549
# 9        074370ed00df096bcea30529d912b4d4  000126baf2f8839eed1df6a726f79549
# 10       b84240d479885eaaf15eb743748cbead  000126baf2f8839eed1df6a726f79549
# ...
