# %% [markdown]
# # Tommy's new internship

# %% [markdown]
# ## subtitle
#
# this is a paragraph where I explain stuff.

# %% [markdown]
# ## equations
#
# This is an inline equation $y = mx + b$.
#
# This is a standalone equation:
#
# $$
# y = mx + b
# $$

# %%
# imports library numpy with name np
import numpy as np
# imports the module pyplot of matplotlib as plt
import matplotlib.pyplot as plt

# jupyter magic command to allow plots to show up
# %matplotlib inline

# %%
x = np.array([0,1,2,3,4])
m = 3.
b = 2.
y = m*x +b

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)
plt.plot(x,y)

# %%
import pandas as pd

# %%
df = pd.read_csv('ignored_assets/paxout_table.csv')
# this converts to datetime
df['time_bucket'] = pd.to_datetime(df['time_bucket'])
df = df.set_index('time_bucket')

# %%
df.sum(axis=1).plot()
